# %%
import numpy as np
import pandas as pd
import os
from gensim.test.utils import get_tmpfile
from gensim.models import Word2Vec
import itertools
from sklearn.cluster import KMeans
import matplotlib
import matplotlib.pyplot as plt

n = 2
w = 6

# %%
path = r"data\\"

# %%
abspath, folders, files = next(os.walk(path))
topFolders = [os.path.join(abspath, f) for f in folders]
topFiles = [f for f in files if not f.startswith('.')]

# %%
abspath, folders, files
# Out:
# ('data\\\\', ['CeeInject', 'Challenge', 'Renos'], ['.DS_Store', 'top20.txt'])

# %%
exec(f'top20 = {open(os.path.join(abspath, topFiles[0])).read()}')

# %%
top20 = [x.lower() for x in top20]

# %%
data = dict(
    (folders[f], os.listdir(g)) for f, g in enumerate(topFolders))

# %%
def parse_files(folder, file):
    arr = np.array(open(os.path.join(path, folder, file)).read().split())
    return arr

class DataIterator():
    
    def __init__(self, malwareType):
        self.malwareType = malwareType
        self.filelist = data[malwareType]
        self.fileiter = iter(self.filelist)
        self.nextdata = parse_files(self.malwareType, next(self.fileiter))
        self.dataiter = iter(self.nextdata)
    
    def __iter__(self):
        return self
    
    def __next__(self):
        try:
            code = next(self.dataiter)
            return [code]
        except StopIteration:
            self.nextdata = parse_files(self.malwareType, next(self.fileiter))
            self.dataiter = iter(self.nextdata)
            return next(self)

# %%
combos = list(itertools.combinations(top20, 2))

# %%
def modelGen(malwareType):
    # Data Iterator for Word2Vec
    d = DataIterator(malwareType)
    
    # Word2Vec
    fname = f'{malwareType}_w2v.model'
    file = get_tmpfile(fname)
    model = Word2Vec(d, size=n, window=w, workers=8)
    model.save(fname)
    
    # DataFrame of cosine similarities
    model_sim = pd.DataFrame(columns=top20, index=top20)
    for i, j in combos:
        model_sim[i][j] = model_sim[j][i] = model.wv.n_similarity([i], [j])
    model_sim = model_sim.fillna(1.0)
    
    return {"file": file, "diter": d, "model": model, "cos_sim": model_sim}

# %%
folders[:1]
# Out:
# ['CeeInject']

# %%
model_gen = dict((f, modelGen(f)) for f in folders)

# %%
word_vectors = model_gen['CeeInject']['model'].wv
ls = []
for i in list(word_vectors.vocab.keys()):
    ls.append((i, word_vectors[i]))

# %%
word_vectors2 = model_gen['Renos']['model'].wv
ls2 = []
for i in list(word_vectors2.vocab.keys()):
    ls2.append((i, word_vectors2[i]))

# %%
def color(x):
    if x == '-':
        return ""
    if x >= 0.95:
        return "background: red"
    if 0.75 <= x and x < 0.95:
        return "background: orange"
    if 0.50 <= x and x < 0.75:
        return "background: yellow"
    return ""

# %%
test_df = model_gen['CeeInject']['cos_sim']
test_df.style.apply(lambda x: [color(v) for v in x], axis = 1)
# Out:
# <style  type="text/css" >
#     #T_8197181a_1d3b_11ea_b93f_70bc10681b34row0_col0 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row0_col10 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row0_col12 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row0_col13 {
#             background:  orange;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row0_col19 {
#             background:  orange;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row1_col1 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row1_col2 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row1_col5 {
#             background:  orange;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row1_col6 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row1_col7 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row1_col11 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row1_col14 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row1_col16 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row2_col1 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row2_col2 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row2_col3 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row2_col5 {
#             background:  orange;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row2_col6 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row2_col9 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row2_col11 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row2_col14 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row2_col15 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row2_col17 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row3_col2 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row3_col3 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row3_col8 {
#             background:  orange;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row3_col9 {
#             background:  orange;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row3_col11 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row3_col15 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row3_col17 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row3_col18 {
#             background:  orange;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row4_col4 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row4_col7 {
#             background:  orange;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row4_col10 {
#             background:  orange;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row4_col12 {
#             background:  orange;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row4_col13 {
#             background:  orange;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row4_col16 {
#             background:  orange;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row4_col19 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row5_col1 {
#             background:  orange;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row5_col2 {
#             background:  orange;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row5_col5 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row5_col6 {
#             background:  orange;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row5_col9 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row5_col11 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row5_col14 {
#             background:  orange;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row6_col1 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row6_col2 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row6_col5 {
#             background:  orange;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row6_col6 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row6_col7 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row6_col11 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row6_col14 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row6_col16 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row7_col1 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row7_col4 {
#             background:  orange;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row7_col6 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row7_col7 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row7_col10 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row7_col12 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row7_col14 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row7_col16 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row8_col3 {
#             background:  orange;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row8_col8 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row8_col9 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row8_col15 {
#             background:  orange;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row8_col17 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row8_col18 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row9_col2 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row9_col3 {
#             background:  orange;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row9_col5 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row9_col8 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row9_col9 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row9_col11 {
#             background:  orange;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row9_col15 {
#             background:  orange;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row9_col17 {
#             background:  orange;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row9_col18 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row10_col0 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row10_col4 {
#             background:  orange;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row10_col7 {
#             background:  yellow;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row10_col10 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row10_col12 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row10_col13 {
#             background:  red;
#         }    #T_8197181a_1d3b_11ea_b93f_70bc10681b34row10_col1

# %%
test_df2 = model_gen['Renos']['cos_sim']
test_df2.style.apply(lambda x: [color(v) for v in x], axis = 1)
# Out:
# <style  type="text/css" >
#     #T_8229472e_1d3b_11ea_91b0_70bc10681b34row0_col0 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row0_col10 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row0_col12 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row0_col13 {
#             background:  orange;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row0_col19 {
#             background:  orange;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row1_col1 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row1_col2 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row1_col5 {
#             background:  orange;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row1_col6 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row1_col7 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row1_col11 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row1_col14 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row1_col16 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row2_col1 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row2_col2 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row2_col3 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row2_col5 {
#             background:  orange;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row2_col6 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row2_col9 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row2_col11 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row2_col14 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row2_col15 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row2_col17 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row3_col2 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row3_col3 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row3_col8 {
#             background:  orange;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row3_col9 {
#             background:  orange;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row3_col11 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row3_col15 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row3_col17 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row3_col18 {
#             background:  orange;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row4_col4 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row4_col7 {
#             background:  orange;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row4_col10 {
#             background:  orange;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row4_col12 {
#             background:  orange;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row4_col13 {
#             background:  orange;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row4_col16 {
#             background:  orange;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row4_col19 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row5_col1 {
#             background:  orange;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row5_col2 {
#             background:  orange;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row5_col5 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row5_col6 {
#             background:  orange;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row5_col9 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row5_col11 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row5_col14 {
#             background:  orange;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row6_col1 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row6_col2 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row6_col5 {
#             background:  orange;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row6_col6 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row6_col7 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row6_col11 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row6_col14 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row6_col16 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row7_col1 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row7_col4 {
#             background:  orange;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row7_col6 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row7_col7 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row7_col10 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row7_col12 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row7_col14 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row7_col16 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row8_col3 {
#             background:  orange;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row8_col8 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row8_col9 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row8_col15 {
#             background:  orange;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row8_col17 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row8_col18 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row9_col2 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row9_col3 {
#             background:  orange;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row9_col5 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row9_col8 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row9_col9 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row9_col11 {
#             background:  orange;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row9_col15 {
#             background:  orange;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row9_col17 {
#             background:  orange;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row9_col18 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row10_col0 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row10_col4 {
#             background:  orange;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row10_col7 {
#             background:  yellow;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row10_col10 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row10_col12 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row10_col13 {
#             background:  red;
#         }    #T_8229472e_1d3b_11ea_91b0_70bc10681b34row10_col1
